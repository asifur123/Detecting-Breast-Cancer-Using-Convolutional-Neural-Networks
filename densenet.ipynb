# %%
import numpy as np 
import pandas as pd 
import os

# %%
from tensorflow import keras
import cv2
from tensorflow.keras.preprocessing.image import load_img ,img_to_array
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D,AveragePooling2D,BatchNormalization
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.layers import Flatten,Dropout,SpatialDropout2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import Adam

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Breast Cancer/Dataset_BUSI/Dataset_BUSI_with_GT"
dir_list = [os.path.join(path,i) for i in os.listdir(path)]
size_dict = {}
for i,value in enumerate(dir_list):
    size_dict[os.listdir(path)[i]] = len(os.listdir(value))
size_dict
# Out:
# {'benign': 891, 'normal': 266, 'malignant': 421}

# %%
import re
def clean(name):
    name = re.sub('[benign ().p]','',str(name))
    return name

# %%
df = pd.DataFrame(os.listdir(dir_list[0]))
# df = df.apply(str,axis=1)
df = df[0].apply(clean)
# print(df.info())
df = df[~df.str.contains('mask',regex =False)]
df = df.apply(int)
df_list = list(df)
type(df_list)
df_list.sort()
print(len(df_list))
# Out:
# 437

# %%
img_size = 128
img_channel = 3
X_b , Xm_b , y_b = np.zeros((437,img_size,img_size,img_channel)) , np.zeros((437,img_size,img_size,img_channel)) , np.full(437,'benign') 
X_n , Xm_n , y_n = np.zeros((133,img_size,img_size,img_channel)) , np.zeros((133,img_size,img_size,img_channel)) , np.full(133,'normal') 
X_m , Xm_m , y_m = np.zeros((210,img_size,img_size,img_channel)) , np.zeros((210,img_size,img_size,img_channel)) , np.full(210,'malignant')

# %%
img1_path = os.path.join(os.path.join(path,'benign'),os.listdir(os.path.join(path,'benign'))[1])

pil_img = load_img(img1_path,color_mode = 'rgb',target_size=(img_size,img_size))
img = img_to_array(pil_img)
img_shape = img.shape
print(img_shape)

def img_num(filename):
    
    val = 0
    
    for i in range(len(filename)) :
        if filename[i] == '(' :
            while True :
                i += 1
                if filename[i] == ')' :
                    break
                val = (val*10) + int(filename[i])
            break
    
    return val

for tumor_path in dir_list :
    for image in os.listdir(tumor_path) :
        p = os.path.join(tumor_path, image)
        pil_img = load_img(p,color_mode = 'rgb',target_size=(img_size,img_size))         # read image as  grayscale ans resize it
        
        if image[-5] == ')' :                                   #if real image 
            
            if image[0] == 'b' :
                X_b[img_num(image)-1]+= img_to_array(pil_img)  # If image is real add it
            if image[0] == 'n' :                               # to X as benign , normal
                X_n[img_num(image)-1]+= img_to_array(pil_img)  # or malignant.
            if image[0] == 'm' :
                X_m[img_num(image)-1]+= img_to_array(pil_img)
        else :                                                 #else masked image
            
            if image[0] == 'b' :
                Xm_b[img_num(image)-1]+= img_to_array(pil_img)  # Similarly add the target
            if image[0] == 'n' :                               # mask to y.
                Xm_n[img_num(image)-1]+= img_to_array(pil_img)
            if image[0] == 'm' :
                Xm_m[img_num(image)-1]+= img_to_array(pil_img)
# Out:
# (128, 128, 3)

# %%
X = np.concatenate((X_b, X_n, X_m), axis = 0)
Xm = np.concatenate((Xm_b, Xm_n, Xm_m), axis = 0)
y = np.concatenate((y_b, y_n, y_m), axis = 0)

print(X.shape)
print(Xm.shape)
print(y.shape)
X /= 255.0
Xm /= 255.0

print(X.max())
print(Xm.min())
# Out:
# (780, 128, 128, 3)
# (780, 128, 128, 3)
# (780,)
# 1.0
# 0.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

encoder  = OneHotEncoder()
# y = y.toarray()
y=encoder.fit_transform(y.reshape(y.shape[0],1))

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.15,shuffle=True,random_state=42)
Xm_train,Xm_test,ym_train,ym_test = train_test_split(Xm,y,test_size = 0.15,shuffle=True,random_state=42,stratify=y.toarray())

class_list = encoder.categories_
print(X_train.shape,X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (663, 128, 128, 3) (117, 128, 128, 3)
# (663, 3) (117, 3)

# %%
from sklearn.metrics import f1_score,roc_auc_score,roc_curve,cohen_kappa_score,precision_score,recall_score
from sklearn.metrics import confusion_matrix,classification_report

def evaluation(model,X_train,y_train,X_val,y_val,X_test,y_test,history):

    train_loss , train_acc = model.evaluate(X_train,y_train.toarray())
    val_loss, val_acc = model.evaluate(X_val,y_val.toarray())
    test_loss_value , test_accuracy = model.evaluate(X_test, y_test.toarray())
    y_pred = model.predict(X_test)
    y_pred_label = np.argmax(y_pred,axis=1)
    y_true_label = np.argmax(y_test,axis=1)
    cm = confusion_matrix(y_true_label, y_pred_label)
    print(cm)
    print(classification_report(y_true_label, y_pred_label))
    f1_measure = f1_score(y_true_label,y_pred_label,average='weighted')
    precisionScore=precision_score(y_true_label,y_pred_label,average='weighted')
    recallScore=recall_score(y_true_label,y_pred_label,average='weighted')
    roc_score = roc_auc_score(y_test.toarray(),y_pred)
    kappa_score = cohen_kappa_score(y_true_label,y_pred_label)

    print("Train accuracy = "+str(train_acc))
    print("Validation accuracy = "+str(val_acc))
    print('Test accuracy = ' + str(test_accuracy))
    print("F1 Score = "+str(f1_measure))
    print("Precision Score = "+str(precisionScore))
    print("Recall Score = "+str(recallScore))
    print("KAPPA = "+str(kappa_score))
    print("ROC Area = "+str(roc_score))

# %%
import matplotlib.pyplot as plt
def Train_Val_Plot(acc,val_acc,loss,val_loss):
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize= (15,10))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])


    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


def fit_evaluate(model,X_train,y_train,X_test,y_test,bs,Epochs,patience):
    es = EarlyStopping(monitor='val_loss', mode='min', patience=patience,restore_best_weights=True, verbose=1)
    X1_train,X_val,y1_train,y_val = train_test_split(X_train,y_train,test_size=0.1,random_state=42,stratify = y_train.toarray())
    history = model.fit(X1_train,y1_train.toarray(),batch_size = bs,epochs=Epochs,validation_data = (X_val,y_val.toarray()), callbacks=[es])
    evaluation(model,X1_train,y1_train,X_val,y_val,X_test,y_test,history)
    Train_Val_Plot(history.history['acc'],history.history['val_acc'],history.history['loss'],history.history['val_loss'])

# %%
base_model = tf.keras.applications.DenseNet121(
                include_top=False,
                weights="imagenet",
                input_tensor=None,
                input_shape=img_shape,
                pooling=None,
            )
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 2s 0us/step

# %%
def DenseNet():

    model = Sequential()
    model.add(base_model)
    
    model.add(Flatten())
    model.add(BatchNormalization())
    model.add(Dense(512,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3,activation='softmax'))
    
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])
    
    return model

# %%
model = DenseNet()
model.summary()
fit_evaluate(model,X_train,y_train,X_test,y_test,16,30,4)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 4, 4, 1024)        7037504
#
#  flatten (Flatten)           (None, 16384)             0
#
#  batch_normalization (BatchN  (None, 16384)            65536
#  ormalization)
#
#  dense (Dense)               (None, 512)               8389120
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 15,664,835
# Trainable params: 8,594,563
# Non-trainable params: 7,070,272
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 20s 132ms/step - loss: 3.2384 - acc: 0.4312 - val_loss: 1.9895 - val_acc: 0.5672
# Epoch 2/30
# 38/38 [==============================] - 1s 34ms/step - loss: 2.7973 - acc: 0.4983 - val_loss: 1.1560 - val_acc: 0.7612
# Epoch 3/30
# 38/38 [==============================] - 1s 34ms/step - loss: 2.1134 - acc: 0.5520 - val_loss: 0.7758 - val_acc: 0.7313
# Epoch 4/30
# 38/38 [==============================] - 1s 32ms/step - loss: 1.8100 - acc: 0.5436 - val_loss: 0.9012 - val_acc: 0.6716
# Epoch 5/30
# 38/38 [==============================] - 1s 34ms/step - loss: 1.6782 - acc: 0.5101 - val_loss: 0.8219 - val_acc: 0.7612
# Epoch 6/30
# 38/38 [==============================] - 1s 39ms/step - loss: 1.5482 - acc: 0.5688 - val_loss: 0.7587 - val_acc: 0.7612
# Epoch 7/30
# 38/38 [==============================] - 1s 28ms/step - loss: 1.0774 - acc: 0.6141 - val_loss: 0.7920 - val_acc: 0.7612
# Epoch 8/30
# 38/38 [==============================] - 1s 32ms/step - loss: 1.1013 - acc: 0.6225 - val_loss: 0.7106 - val_acc: 0.7313
# Epoch 9/30
# 38/38 [==============================] - 1s 28ms/step - loss: 1.0322 - acc: 0.6477 - val_loss: 0.7341 - val_acc: 0.7313
# Epoch 10/30
# 38/38 [==============================] - 1s 28ms/step - loss: 0.9765 - acc: 0.6711 - val_loss: 0.7573 - val_acc: 0.7463
# Epoch 11/30
# 38/38 [==============================] - 1s 33ms/step - loss: 0.7056 - acc: 0.7265 - val_loss: 0.6862 - val_acc: 0.7015
# Epoch 12/30
# 38/38 [==============================] - 1s 29ms/step - loss: 0.7798 - acc: 0.6896 - val_loss: 0.9458 - val_acc: 0.7015
# Epoch 13/30
# 38/38 [==============================] - 1s 28ms/step - loss: 0.7207 - acc: 0.7198 - val_loss: 0.8693 - val_acc: 0.7015
# Epoch 14/30
# 38/38 [==============================] - 1s 34ms/step - loss: 0.6708 - acc: 0.7282 - val_loss: 0.6848 - val_acc: 0.7313
# Epoch 15/30
# 38/38 [==============================] - 1s 31ms/step - loss: 0.5233 - acc: 0.7869 - val_loss: 0.7253 - val_acc: 0.7313
# Epoch 16/30
# 38/38 [==============================] - 1s 33ms/step - loss: 0.6032 - acc: 0.7953 - val_loss: 0.6960 - val_acc: 0.7612
# Epoch 17/30
# 38/38 [==============================] - 1s 33ms/step - loss: 0.4730 - acc: 0.8188 - val_loss: 0.7303 - val_acc: 0.7612
# Epoch 18/30
# 37/38 [============================>.] - ETA: 0s - loss: 0.3990 - acc: 0.8395Restoring model weights from the end of the best epoch: 14.
# 38/38 [==============================] - 1s 36ms/step - loss: 0.3983 - acc: 0.8389 - val_loss: 1.1239 - val_acc: 0.7313
# Epoch 18: early stopping
# 19/19 [==============================] - 3s 82ms/step - loss: 0.3910 - acc: 0.9044
# 3/3 [==============================] - 0s 149ms/step - loss: 0.6848 - acc: 0.7313
# 4/4 [==============================] - 1s 353ms/step - loss: 0.7212 - acc: 0.7436
# 4/4 [==============================] - 2s 45ms/step
# [[50  4  4]
#  [13 23  1]
#  [ 7  1 14]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.86      0.78        58
#            1       0.82      0.62      0.71        37
#            2       0.74      0.64      0.68        22
#
#     accuracy                           0.74       117
#    macro avg       0.76      0.71      0.72       117
# weighted avg       0.75      0.74      0.74       117
#
# Train accuracy = 0.9043624401092529
# Validation accuracy = 0.7313432693481445
# Test accuracy = 0.7435897588729858
# F1 Score = 0.7395000481069899
# Precision Score = 0.7524098708309234
# Recall Score = 0.7435897435897436
# KAPPA = 0.5706422018348625
# ROC Area = 0.8797645427440254

# %%
model = DenseNet()
model.summary()
fit_evaluate(model,Xm_train,ym_train,Xm_test,ym_test,16,30,4)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 4, 4, 1024)        7037504
#
#  flatten_1 (Flatten)         (None, 16384)             0
#
#  batch_normalization_1 (Batc  (None, 16384)            65536
#  hNormalization)
#
#  dense_5 (Dense)             (None, 512)               8389120
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 15,664,835
# Trainable params: 8,594,563
# Non-trainable params: 7,070,272
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 12s 113ms/step - loss: 3.9590 - acc: 0.6141 - val_loss: 2.7126 - val_acc: 0.8806
# Epoch 2/30
# 38/38 [==============================] - 1s 35ms/step - loss: 2.0957 - acc: 0.7886 - val_loss: 1.2652 - val_acc: 0.8955
# Epoch 3/30
# 38/38 [==============================] - 1s 35ms/step - loss: 1.5417 - acc: 0.8674 - val_loss: 1.0074 - val_acc: 0.9104
# Epoch 4/30
# 38/38 [==============================] - 1s 29ms/step - loss: 1.5144 - acc: 0.8557 - val_loss: 1.1997 - val_acc: 0.9104
# Epoch 5/30
# 38/38 [==============================] - 1s 34ms/step - loss: 1.2989 - acc: 0.8658 - val_loss: 0.8066 - val_acc: 0.9254
# Epoch 6/30
# 38/38 [==============================] - 1s 33ms/step - loss: 0.9704 - acc: 0.9161 - val_loss: 0.7288 - val_acc: 0.9254
# Epoch 7/30
# 38/38 [==============================] - 1s 33ms/step - loss: 0.9105 - acc: 0.9211 - val_loss: 0.6048 - val_acc: 0.9104
# Epoch 8/30
# 38/38 [==============================] - 1s 28ms/step - loss: 0.5030 - acc: 0.9312 - val_loss: 0.6899 - val_acc: 0.8955
# Epoch 9/30
# 38/38 [==============================] - 1s 34ms/step - loss: 0.6791 - acc: 0.9329 - val_loss: 1.1013 - val_acc: 0.9104
# Epoch 10/30
# 38/38 [==============================] - 1s 33ms/step - loss: 0.7405 - acc: 0.9362 - val_loss: 0.7623 - val_acc: 0.9254
# Epoch 11/30
# 38/38 [==============================] - ETA: 0s - loss: 0.6552 - acc: 0.9346Restoring model weights from the end of the best epoch: 7.
# 38/38 [==============================] - 1s 39ms/step - loss: 0.6552 - acc: 0.9346 - val_loss: 0.6386 - val_acc: 0.9254
# Epoch 11: early stopping
# 19/19 [==============================] - 1s 38ms/step - loss: 0.0768 - acc: 0.9849
# 3/3 [==============================] - 0s 30ms/step - loss: 0.6048 - acc: 0.9104
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0455 - acc: 0.9829
# 4/4 [==============================] - 2s 28ms/step
# [[65  1  0]
#  [ 1 30  0]
#  [ 0  0 20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        66
#            1       0.97      0.97      0.97        31
#            2       1.00      1.00      1.00        20
#
#     accuracy                           0.98       117
#    macro avg       0.98      0.98      0.98       117
# weighted avg       0.98      0.98      0.98       117
#
# Train accuracy = 0.9848993420600891
# Validation accuracy = 0.9104477763175964
# Test accuracy = 0.9829059839248657
# F1 Score = 0.9829059829059829
# Precision Score = 0.9829059829059829
# Recall Score = 0.9829059829059829
# KAPPA = 0.9706472654290015
# ROC Area = 0.9993018159471537

# %%
base_model2 = tf.keras.applications.DenseNet169(
                include_top=False,
                weights="imagenet",
                input_tensor=None,
                input_shape=img_shape,
                pooling=None,
            )
for layer in base_model2.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 3s 0us/step

# %%
def DenseNet169():

    model = Sequential()
    model.add(base_model2)
    
    model.add(Flatten())
    model.add(BatchNormalization())
    model.add(Dense(512,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3,activation='softmax'))
    
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])
    
    return model

# %%
model = DenseNet169()
model.summary()
fit_evaluate(model,X_train,y_train,X_test,y_test,16,30,4)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 4, 4, 1664)        12642880
#
#  flatten_2 (Flatten)         (None, 26624)             0
#
#  batch_normalization_2 (Batc  (None, 26624)            106496
#  hNormalization)
#
#  dense_10 (Dense)            (None, 512)               13632000
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_11 (Dense)            (None, 256)               131328
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 128)               32896
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_14 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 26,554,051
# Trainable params: 13,857,923
# Non-trainable params: 12,696,128
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 17s 163ms/step - loss: 3.8807 - acc: 0.4396 - val_loss: 2.2760 - val_acc: 0.5970
# Epoch 2/30
# 38/38 [==============================] - 2s 45ms/step - loss: 3.1034 - acc: 0.5151 - val_loss: 1.1649 - val_acc: 0.7463
# Epoch 3/30
# 38/38 [==============================] - 2s 51ms/step - loss: 2.3612 - acc: 0.5319 - val_loss: 1.0731 - val_acc: 0.6716
# Epoch 4/30
# 38/38 [==============================] - 2s 41ms/step - loss: 2.2278 - acc: 0.5168 - val_loss: 1.1895 - val_acc: 0.6716
# Epoch 5/30
# 38/38 [==============================] - 2s 43ms/step - loss: 1.7545 - acc: 0.5839 - val_loss: 0.9452 - val_acc: 0.6866
# Epoch 6/30
# 38/38 [==============================] - 2s 44ms/step - loss: 1.4489 - acc: 0.6191 - val_loss: 0.9160 - val_acc: 0.7015
# Epoch 7/30
# 38/38 [==============================] - 2s 44ms/step - loss: 1.3027 - acc: 0.6158 - val_loss: 0.7890 - val_acc: 0.7164
# Epoch 8/30
# 38/38 [==============================] - 1s 36ms/step - loss: 1.1813 - acc: 0.5906 - val_loss: 0.8203 - val_acc: 0.6716
# Epoch 9/30
# 38/38 [==============================] - 2s 45ms/step - loss: 1.1451 - acc: 0.6208 - val_loss: 0.7583 - val_acc: 0.7612
# Epoch 10/30
# 38/38 [==============================] - 2s 45ms/step - loss: 1.1234 - acc: 0.6158 - val_loss: 0.7376 - val_acc: 0.7612
# Epoch 11/30
# 38/38 [==============================] - 2s 46ms/step - loss: 0.9065 - acc: 0.6644 - val_loss: 0.7416 - val_acc: 0.7910
# Epoch 12/30
# 38/38 [==============================] - 2s 50ms/step - loss: 0.9378 - acc: 0.6611 - val_loss: 0.7033 - val_acc: 0.7612
# Epoch 13/30
# 38/38 [==============================] - 2s 45ms/step - loss: 0.8133 - acc: 0.6946 - val_loss: 0.6689 - val_acc: 0.7910
# Epoch 14/30
# 38/38 [==============================] - 1s 36ms/step - loss: 0.7448 - acc: 0.7064 - val_loss: 0.7037 - val_acc: 0.7761
# Epoch 15/30
# 38/38 [==============================] - 1s 36ms/step - loss: 0.7077 - acc: 0.7282 - val_loss: 0.7588 - val_acc: 0.7313
# Epoch 16/30
# 38/38 [==============================] - 1s 36ms/step - loss: 0.5739 - acc: 0.7718 - val_loss: 0.8526 - val_acc: 0.7313
# Epoch 17/30
# 37/38 [============================>.] - ETA: 0s - loss: 0.5930 - acc: 0.7804Restoring model weights from the end of the best epoch: 13.
# 38/38 [==============================] - 2s 46ms/step - loss: 0.5917 - acc: 0.7802 - val_loss: 0.7969 - val_acc: 0.7463
# Epoch 17: early stopping
# 19/19 [==============================] - 3s 92ms/step - loss: 0.5191 - acc: 0.8624
# 3/3 [==============================] - 0s 37ms/step - loss: 0.6689 - acc: 0.7910
# 4/4 [==============================] - 1s 217ms/step - loss: 0.7157 - acc: 0.7436
# 4/4 [==============================] - 3s 61ms/step
# [[53  2  3]
#  [12 23  2]
#  [ 9  2 11]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.80        58
#            1       0.85      0.62      0.72        37
#            2       0.69      0.50      0.58        22
#
#     accuracy                           0.74       117
#    macro avg       0.75      0.68      0.70       117
# weighted avg       0.75      0.74      0.73       117
#
# Train accuracy = 0.8624160885810852
# Validation accuracy = 0.7910447716712952
# Test accuracy = 0.7435897588729858
# F1 Score = 0.7342423049659893
# Precision Score = 0.7537099064876842
# Recall Score = 0.7435897435897436
# KAPPA = 0.563758389261745
# ROC Area = 0.8862068852148522

# %%
model = DenseNet169()
model.summary()
fit_evaluate(model,Xm_train,ym_train,Xm_test,ym_test,16,30,4)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 4, 4, 1664)        12642880
#
#  flatten_3 (Flatten)         (None, 26624)             0
#
#  batch_normalization_3 (Batc  (None, 26624)            106496
#  hNormalization)
#
#  dense_15 (Dense)            (None, 512)               13632000
#
#  dropout_12 (Dropout)        (None, 512)               0
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 128)               32896
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 26,554,051
# Trainable params: 13,857,923
# Non-trainable params: 12,696,128
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 16s 163ms/step - loss: 3.5198 - acc: 0.5956 - val_loss: 0.3740 - val_acc: 0.8806
# Epoch 2/30
# 38/38 [==============================] - 1s 37ms/step - loss: 2.7644 - acc: 0.7232 - val_loss: 0.5919 - val_acc: 0.8657
# Epoch 3/30
# 38/38 [==============================] - 1s 35ms/step - loss: 1.7086 - acc: 0.8305 - val_loss: 0.6020 - val_acc: 0.9403
# Epoch 4/30
# 38/38 [==============================] - 1s 35ms/step - loss: 1.1132 - acc: 0.8859 - val_loss: 0.4545 - val_acc: 0.9552
# Epoch 5/30
# 37/38 [============================>.] - ETA: 0s - loss: 0.8336 - acc: 0.9206Restoring model weights from the end of the best epoch: 1.
# 38/38 [==============================] - 2s 46ms/step - loss: 0.8281 - acc: 0.9211 - val_loss: 0.4723 - val_acc: 0.9254
# Epoch 5: early stopping
# 19/19 [==============================] - 1s 43ms/step - loss: 0.1524 - acc: 0.9664
# 3/3 [==============================] - 0s 46ms/step - loss: 0.3740 - acc: 0.8806
# 4/4 [==============================] - 0s 48ms/step - loss: 0.1895 - acc: 0.9487
# 4/4 [==============================] - 3s 58ms/step
# [[64  2  0]
#  [ 4 27  0]
#  [ 0  0 20]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96        66
#            1       0.93      0.87      0.90        31
#            2       1.00      1.00      1.00        20
#
#     accuracy                           0.95       117
#    macro avg       0.96      0.95      0.95       117
# weighted avg       0.95      0.95      0.95       117
#
# Train accuracy = 0.9664429426193237
# Validation accuracy = 0.8805969953536987
# Test accuracy = 0.9487179517745972
# F1 Score = 0.9482459497384871
# Precision Score = 0.9485445814046221
# Recall Score = 0.9487179487179487
# KAPPA = 0.9111617312072893
# ROC Area = 0.9928560571515428

# %%
base_model3 = tf.keras.applications.DenseNet201(
                include_top=False,
                weights="imagenet",
                input_tensor=None,
                input_shape=img_shape,
                pooling=None,
            )
for layer in base_model3.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 4s 0us/step

# %%
def DenseNet201():

    model = Sequential()
    model.add(base_model2)
    
    model.add(Flatten())
    model.add(BatchNormalization())
#     model.add(Dense(512,activation='relu'))
#     model.add(Dropout(0.5))
    model.add(Dense(256,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(64,activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(3,activation='softmax'))
    
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['acc'])
    
    return model

# %%
model = DenseNet201()
model.summary()
fit_evaluate(model,X_train,y_train,X_test,y_test,16,30,4)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 4, 4, 1664)        12642880
#
#  flatten_4 (Flatten)         (None, 26624)             0
#
#  batch_normalization_4 (Batc  (None, 26624)            106496
#  hNormalization)
#
#  dense_20 (Dense)            (None, 256)               6816000
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 128)               32896
#
#  dropout_17 (Dropout)        (None, 128)               0
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_23 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 19,606,723
# Trainable params: 6,910,595
# Non-trainable params: 12,696,128
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 16s 141ms/step - loss: 2.9325 - acc: 0.5017 - val_loss: 2.0987 - val_acc: 0.6567
# Epoch 2/30
# 38/38 [==============================] - 2s 44ms/step - loss: 2.1228 - acc: 0.6141 - val_loss: 1.4884 - val_acc: 0.7463
# Epoch 3/30
# 38/38 [==============================] - 2s 42ms/step - loss: 2.0281 - acc: 0.5889 - val_loss: 1.1941 - val_acc: 0.7313
# Epoch 4/30
# 38/38 [==============================] - 2s 43ms/step - loss: 1.7898 - acc: 0.6292 - val_loss: 1.1480 - val_acc: 0.7313
# Epoch 5/30
# 38/38 [==============================] - 2s 42ms/step - loss: 1.5462 - acc: 0.6544 - val_loss: 1.0226 - val_acc: 0.7313
# Epoch 6/30
# 38/38 [==============================] - 1s 35ms/step - loss: 1.1902 - acc: 0.6862 - val_loss: 1.1971 - val_acc: 0.7015
# Epoch 7/30
# 38/38 [==============================] - 2s 54ms/step - loss: 1.1331 - acc: 0.6930 - val_loss: 0.8986 - val_acc: 0.7313
# Epoch 8/30
# 38/38 [==============================] - 2s 40ms/step - loss: 0.9404 - acc: 0.7198 - val_loss: 0.9252 - val_acc: 0.7164
# Epoch 9/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.8886 - acc: 0.7299 - val_loss: 0.9013 - val_acc: 0.7463
# Epoch 10/30
# 38/38 [==============================] - 2s 43ms/step - loss: 0.7595 - acc: 0.7634 - val_loss: 0.8840 - val_acc: 0.7761
# Epoch 11/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.6792 - acc: 0.8003 - val_loss: 0.9066 - val_acc: 0.7612
# Epoch 12/30
# 38/38 [==============================] - 2s 43ms/step - loss: 0.5984 - acc: 0.7970 - val_loss: 0.8240 - val_acc: 0.7463
# Epoch 13/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.5597 - acc: 0.7903 - val_loss: 0.8918 - val_acc: 0.7761
# Epoch 14/30
# 38/38 [==============================] - 2s 43ms/step - loss: 0.5303 - acc: 0.8171 - val_loss: 0.8082 - val_acc: 0.7761
# Epoch 15/30
# 38/38 [==============================] - 2s 43ms/step - loss: 0.4517 - acc: 0.8372 - val_loss: 0.8432 - val_acc: 0.7761
# Epoch 16/30
# 38/38 [==============================] - 2s 54ms/step - loss: 0.4170 - acc: 0.8591 - val_loss: 0.8038 - val_acc: 0.7910
# Epoch 17/30
# 38/38 [==============================] - 1s 37ms/step - loss: 0.4290 - acc: 0.8658 - val_loss: 0.8615 - val_acc: 0.7910
# Epoch 18/30
# 38/38 [==============================] - 2s 43ms/step - loss: 0.4529 - acc: 0.8507 - val_loss: 0.7745 - val_acc: 0.7463
# Epoch 19/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.3490 - acc: 0.8893 - val_loss: 0.7855 - val_acc: 0.7761
# Epoch 20/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.2945 - acc: 0.9060 - val_loss: 0.8841 - val_acc: 0.7612
# Epoch 21/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.3616 - acc: 0.8909 - val_loss: 0.9354 - val_acc: 0.7612
# Epoch 22/30
# 37/38 [============================>.] - ETA: 0s - loss: 0.2886 - acc: 0.9105Restoring model weights from the end of the best epoch: 18.
# 38/38 [==============================] - 2s 44ms/step - loss: 0.2868 - acc: 0.9111 - val_loss: 0.9014 - val_acc: 0.7612
# Epoch 22: early stopping
# 19/19 [==============================] - 1s 55ms/step - loss: 0.1186 - acc: 0.9832
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7745 - acc: 0.7463
# 4/4 [==============================] - 0s 48ms/step - loss: 0.7112 - acc: 0.7607
# 4/4 [==============================] - 3s 53ms/step
# [[51  5  2]
#  [13 23  1]
#  [ 5  2 15]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.88      0.80        58
#            1       0.77      0.62      0.69        37
#            2       0.83      0.68      0.75        22
#
#     accuracy                           0.76       117
#    macro avg       0.78      0.73      0.75       117
# weighted avg       0.77      0.76      0.76       117
#
# Train accuracy = 0.9832214713096619
# Validation accuracy = 0.746268630027771
# Test accuracy = 0.7606837749481201
# F1 Score = 0.7562877114528307
# Precision Score = 0.7655518394648829
# Recall Score = 0.7606837606837606
# KAPPA = 0.5995599559955996
# ROC Area = 0.9009279383956397

# %%
model = DenseNet201()
model.summary()
fit_evaluate(model,Xm_train,ym_train,Xm_test,ym_test,16,30,4)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 4, 4, 1664)        12642880
#
#  flatten_5 (Flatten)         (None, 26624)             0
#
#  batch_normalization_5 (Batc  (None, 26624)            106496
#  hNormalization)
#
#  dense_24 (Dense)            (None, 256)               6816000
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 128)               32896
#
#  dropout_20 (Dropout)        (None, 128)               0
#
#  dense_26 (Dense)            (None, 64)                8256
#
#  dropout_21 (Dropout)        (None, 64)                0
#
#  dense_27 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 19,606,723
# Trainable params: 6,910,595
# Non-trainable params: 12,696,128
# _________________________________________________________________
# Epoch 1/30
# 38/38 [==============================] - 15s 127ms/step - loss: 2.7152 - acc: 0.6762 - val_loss: 0.5346 - val_acc: 0.9104
# Epoch 2/30
# 38/38 [==============================] - 2s 45ms/step - loss: 1.6841 - acc: 0.8490 - val_loss: 0.3199 - val_acc: 0.9403
# Epoch 3/30
# 38/38 [==============================] - 1s 35ms/step - loss: 1.2774 - acc: 0.8658 - val_loss: 0.3569 - val_acc: 0.9552
# Epoch 4/30
# 38/38 [==============================] - 2s 41ms/step - loss: 0.8178 - acc: 0.9094 - val_loss: 0.4076 - val_acc: 0.9254
# Epoch 5/30
# 38/38 [==============================] - 2s 55ms/step - loss: 0.8516 - acc: 0.9228 - val_loss: 0.2705 - val_acc: 0.9403
# Epoch 6/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.8677 - acc: 0.9161 - val_loss: 0.3878 - val_acc: 0.9104
# Epoch 7/30
# 38/38 [==============================] - 2s 42ms/step - loss: 0.4781 - acc: 0.9480 - val_loss: 0.2076 - val_acc: 0.9254
# Epoch 8/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4148 - acc: 0.9497 - val_loss: 0.3110 - val_acc: 0.9254
# Epoch 9/30
# 38/38 [==============================] - 1s 35ms/step - loss: 0.4679 - acc: 0.9597 - val_loss: 0.3731 - val_acc: 0.9254
# Epoch 10/30
# 38/38 [==============================] - 1s 36ms/step - loss: 0.4483 - acc: 0.9547 - val_loss: 0.2449 - val_acc: 0.9403
# Epoch 11/30
# 37/38 [============================>.] - ETA: 0s - loss: 0.4481 - acc: 0.9611Restoring model weights from the end of the best epoch: 7.
# 38/38 [==============================] - 2s 46ms/step - loss: 0.4451 - acc: 0.9614 - val_loss: 0.3431 - val_acc: 0.9403
# Epoch 11: early stopping
# 19/19 [==============================] - 1s 44ms/step - loss: 0.0419 - acc: 0.9933
# 3/3 [==============================] - 0s 45ms/step - loss: 0.2076 - acc: 0.9254
# 4/4 [==============================] - 0s 54ms/step - loss: 0.3349 - acc: 0.9658
# 4/4 [==============================] - 4s 54ms/step
# [[63  3  0]
#  [ 1 30  0]
#  [ 0  0 20]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97        66
#            1       0.91      0.97      0.94        31
#            2       1.00      1.00      1.00        20
#
#     accuracy                           0.97       117
#    macro avg       0.96      0.97      0.97       117
# weighted avg       0.97      0.97      0.97       117
#
# Train accuracy = 0.9932885766029358
# Validation accuracy = 0.9253731369972229
# Test accuracy = 0.9658119678497314
# F1 Score = 0.9660831689677843
# Precision Score = 0.9670988733488733
# Recall Score = 0.9658119658119658
# KAPPA = 0.941805521014673
# ROC Area = 0.9955243192854066
